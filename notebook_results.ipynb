# %% [markdown]
# ## STAC Model Data Results Notebook

# %%
from IPython.display import HTML
from notebook_utils import get_notebook_paths, process_notebook_results, convert_paths_to_html_links
notebooks_folder_path = "notebooks"
notebook_paths = get_notebook_paths(notebooks_folder_path)
all_results = process_notebook_results(notebook_paths)
all_results_with_links = convert_paths_to_html_links(all_results, notebook_paths)

# %%
HTML(all_results_with_links.to_html(
        escape=False
    ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Model ID</th>
#       <th>Avg Compute Time (Min)</th>
#       <th>Avg Volume Error (%)</th>
#       <th>Avg Precip Excess (in)</th>
#       <th>Max Precip Excess (in)</th>
#       <th>Min Precip Excess (in)</th>
#       <th>HTML_Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BluestoneLocal</td>
#       <td>46.02</td>
#       <td>7.86</td>
#       <td>0.27</td>
#       <td>5.43</td>
#       <td>0.0</td>
#       <td><a href='notebooks/BluestoneLocal.html'>notebooks/BluestoneLocal.html</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BluestoneUpper</td>
#       <td>44.49</td>
#       <td>0.05</td>
#       <td>0.37</td>
#       <td>6.98</td>
#       <td>0.0</td>
#       <td><a href='notebooks/BluestoneUpper.html'>notebooks/BluestoneUpper.html</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Coal</td>
#       <td>104.29</td>
#       <td>0.01</td>
#       <td>0.24</td>
#       <td>4.72</td>
#       <td>0.0</td>
#       <td><a href='notebooks/Coal.html'>notebooks/Coal.html</a></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ElkMiddle</td>
#       <td>19.44</td>
#       <td>0.02</td>
#       <td>0.11</td>
#       <td>2.42</td>
#       <td>0.0</td>
#       <td><a href='notebooks/ElkMiddle.html'>notebooks/ElkMiddle.html</a></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ElkSutton</td>
#       <td>20.11</td>
#       <td>0.00</td>
#       <td>0.05</td>
#       <td>1.53</td>
#       <td>0.0</td>
#       <td><a href='notebooks/ElkSutton.html'>notebooks/ElkSutton.html</a></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>GauleyLower</td>
#       <td>255.63</td>
#       <td>0.12</td>
#       <td>0.28</td>
#       <td>3.86</td>
#       <td>0.0</td>
#       <td><a href='notebooks/GauleyLower.html'>notebooks/GauleyLower.html</a></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>GauleySummersville</td>
#       <td>20.29</td>
#       <td>2522.28</td>
#       <td>0.24</td>
#       <td>2.94</td>
#       <td>0.0</td>
#       <td><a href='notebooks/GauleySummersville.html'>notebooks/GauleySummersville.html</a></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Greenbrier</td>
#       <td>24.32</td>
#       <td>0.02</td>
#       <td>0.40</td>
#       <td>6.36</td>
#       <td>0.0</td>
#       <td><a href='notebooks/Greenbrier.html'>notebooks/Greenbrier.html</a></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Little</td>
#       <td>11.62</td>
#       <td>0.01</td>
#       <td>0.12</td>
#       <td>2.27</td>
#       <td>0.0</td>
#       <td><a href='notebooks/Little.html'>notebooks/Little.html</a></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>LowerKanawha</td>
#       <td>15.98</td>
#       <td>0.06</td>
#       <td>0.24</td>
#       <td>2.57</td>
#       <td>0.0</td>
#       <td><a href='notebooks/LowerKanawha.html'>notebooks/LowerKanawha.html</a></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>LowerNew</td>
#       <td>43.46</td>
#       <td>122.07</td>
#       <td>0.20</td>
#       <td>3.06</td>
#       <td>0.0</td>
#       <td><a href='notebooks/LowerNew.html'>notebooks/LowerNew.html</a></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>MiddleNew</td>
#       <td>60.36</td>
#       <td>0.01</td>
#       <td>0.28</td>
#       <td>4.58</td>
#       <td>0.0</td>
#       <td><a href='notebooks/MiddleNew.html'>notebooks/MiddleNew.html</a></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>UpperKanawha</td>
#       <td>52.07</td>
#       <td>0.01</td>
#       <td>0.12</td>
#       <td>2.65</td>
#       <td>0.0</td>
#       <td><a href='notebooks/UpperKanawha.html'>notebooks/UpperKanawha.html</a></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>UpperNew</td>
#       <td>39.36</td>
#       <td>0.00</td>
#       <td>0.17</td>
#       <td>2.79</td>
#       <td>0.0</td>
#       <td><a href='notebooks/UpperNew.html'>notebooks/UpperNew.html</a></td>
#     </tr>
#   </tbody>
# </table>
